# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image

# %%
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en', 'hi'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
filename = "image.png"

# %%
Image(filename)

# %%
output = reader.readtext(filename)

# %%
output
# Out:
# [([[0, 0], [876, 0], [876, 72], [0, 72]],
#   'सभी मनुष्यों को गौरव और अधिकारों के मामले में जन्मजात',
#   0.00012217057519592345),
#  ([[0, 50], [864, 50], [864, 125], [0, 125]],
#   'स्वतन्त्रता और समानता प्राप्त है| उन्हें बुद्धि और अन्तरात्मा',
#   0.0170925110578537),
#  ([[0, 107], [862, 107], [862, 171], [0, 171]],
#   'की देन प्राप्त है और परस्पर उन्हें भाईचारे के भाव से बर्ताव',
#   0.0009357152157463133),
#  ([[0, 164], [221, 164], [221, 214], [0, 214]],
#   'करना चाहिए|',
#   0.126898854970932)]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-6ec5c0a09f89> in <module>
# ----> 1 cord = output[4][0]
#
# IndexError: list index out of range
